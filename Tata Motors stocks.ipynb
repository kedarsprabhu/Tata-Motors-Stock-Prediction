# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %%
df=pd.read_csv("D:\TATAMOTORS.NS.csv")
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  03-11-2020  135.000000  137.399994  133.550003  134.100006  134.100006
# 1  04-11-2020  135.600006  137.000000  134.000000  135.899994  135.899994
# 2  05-11-2020  137.000000  138.000000  136.000000  137.649994  137.649994
# 3  06-11-2020  137.649994  142.300003  137.649994  139.000000  139.000000
# 4  09-11-2020  140.600006  141.500000  138.699997  141.000000  141.000000
#
#        Volume
# 0  52071476.0
# 1  44675934.0
# 2  38928602.0
# 3  67966815.0
# 4  40277460.0

# %%
df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 244  28-10-2021  493.899994  493.899994  478.549988  481.049988  481.049988
# 245  29-10-2021  482.000000  491.600006  467.700012  483.700012  483.700012
# 246  01-11-2021  486.450012  489.700012  469.799988  485.700012  485.700012
# 247  02-11-2021  506.500000  510.000000  486.500000  487.850006  487.850006
# 248  03-11-2021  483.799988  495.000000  481.600006  484.899994  484.899994
#
#          Volume
# 244  25182748.0
# 245  31054342.0
# 246  34315690.0
# 247  51580720.0
# 248  22936533.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       249 non-null    object
#  1   Open       248 non-null    float64
#  2   High       248 non-null    float64
#  3   Low        248 non-null    float64
#  4   Close      248 non-null    float64
#  5   Adj Close  248 non-null    float64
#  6   Volume     248 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.7+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-03-11  135.000000  137.399994  133.550003  134.100006  134.100006
# 1 2020-04-11  135.600006  137.000000  134.000000  135.899994  135.899994
# 2 2020-05-11  137.000000  138.000000  136.000000  137.649994  137.649994
# 3 2020-06-11  137.649994  142.300003  137.649994  139.000000  139.000000
# 4 2020-09-11  140.600006  141.500000  138.699997  141.000000  141.000000
#
#        Volume
# 0  52071476.0
# 1  44675934.0
# 2  38928602.0
# 3  67966815.0
# 4  40277460.0

# %%
df = df[["Date","Close"]] 
# Rename the features: These names are required for the model fitting
df = df.rename(columns = {"Date":"ds","Close":"y"}) 
df.head()
# Out:
#           ds           y
# 0 2020-03-11  134.100006
# 1 2020-04-11  135.899994
# 2 2020-05-11  137.649994
# 3 2020-06-11  139.000000
# 4 2020-09-11  141.000000

# %%
from fbprophet import Prophet

# %%
kt=Prophet(daily_seasonality= True)
kt.fit(df)
future = kt.make_future_dataframe(periods=730) 
future.head()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
#           ds
# 0 2020-01-12
# 1 2020-02-12
# 2 2020-03-11
# 3 2020-03-12
# 4 2020-04-11

# %%
forecast=kt.predict(future)

# %%
forecast.tail()
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 974 2023-12-06  676.976411  561.896744  706.840274   676.801253   677.146708
# 975 2023-12-07  677.333166  564.562949  718.961074   677.157502   677.503799
# 976 2023-12-08  677.689922  549.764995  704.287653   677.513751   677.860890
# 977 2023-12-09  678.046677  560.889589  710.157689   677.870024   678.217981
# 978 2023-12-10  678.403432  564.572831  710.566561   678.226549   678.574752
#
#      additive_terms  additive_terms_lower  additive_terms_upper      daily  \
# 974      -41.996611            -41.996611            -41.996611 -42.089905
# 975      -35.409869            -35.409869            -35.409869 -42.089905
# 976      -49.705861            -49.705861            -49.705861 -42.089905
# 977      -42.224320            -42.224320            -42.224320 -42.089905
# 978      -40.562203            -40.562203            -40.562203 -42.089905
#
#      daily_lower  daily_upper    weekly  weekly_lower  weekly_upper  \
# 974   -42.089905   -42.089905  0.093294      0.093294      0.093294
# 975   -42.089905   -42.089905  6.680036      6.680036      6.680036
# 976   -42.089905   -42.089905 -7.615957     -7.615957     -7.615957
# 977   -42.089905   -42.089905 -0.134415     -0.134415     -0.134415
# 978   -42.089905   -42.089905  1.527702      1.527702      1.527702
#
#      multiplicative_terms  multiplicative_terms_lower  \
# 974                   0.0                         0.0
# 975                   0.0                         0.0
# 976                   0.0                         0.0
# 977                   0.0                         0.0
# 978                   0.0                         0.0
#
#      multiplicative_terms_upper        yhat
# 974                         0.0  634.979800
# 975                         0.0  641.923297
# 976                         0.0  627.984060
# 977                         0.0  635.822357
# 978                         0.0  637.841229

# %%
forecast.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'daily', 'daily_lower', 'daily_upper', 'weekly', 'weekly_lower',
#        'weekly_upper', 'multiplicative_terms', 'multiplicative_terms_lower',
#        'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 974 2023-12-06  634.979800  561.896744  706.840274
# 975 2023-12-07  641.923297  564.562949  718.961074
# 976 2023-12-08  627.984060  549.764995  704.287653
# 977 2023-12-09  635.822357  560.889589  710.157689
# 978 2023-12-10  637.841229  564.572831  710.566561

# %%
from fbprophet.plot import plot_plotly, plot_components_plotly

# %%
plot_plotly(kt, forecast)
# Out:
# <div>                            <div id="a4c72265-9589-488b-9aa9-41bb590ffa32" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4c72265-9589-488b-9aa9-41bb590ffa32")) {                    Plotly.newPlot(                        "a4c72265-9589-488b-9aa9-41bb590ffa32",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","type":"scatter","x":["2020-01-12T00:00:00","2020-02-12T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-05-11T00:00:00","2020-06-11T00:00:00","2020-07-12T00:00:00","2020-08-12T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-10-11T00:00:00","2020-10-12T00:00:00","2020-11-11T00:00:00","2020-11-12T00:00:00","2020-11-13T00:00:00","2020-11-17T00:00:00","2020-11-18T00:00:00","2020-11-19T00:00:00","2020-11-20T00:00:00","2020-11-23T00:00:00","2020-11-24T00:00:00","2020-11-25T00:00:00","2020-11-26T00:00:00","2020-11-27T00:00:00","2020-12-11T00:00:00","2020-12-14T00:00:00","2020-12-15T00:00:00","2020-12-16T00:00:00","2020-12-17T00:00:00","2020-12-18T00:00:00","2020-12-21T00:00:00","2020-12-22T00:00:00","2020-12-23T00:00:00","2020-12-24T00:00:00","2020-12-28T00:00:00","2020-12-29T00:00:00","2020-12-30T00:00:00","2020-12-31T00:00:00","2021-01-01T00:00:00","2021-01-02T00:00:00","2021-01-03T00:00:00","2021-01-04T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-09T00:00:00","2021-01-10T00:00:00","2021-01-11T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-06T00:00:00","2021-02-07T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-11T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-05T00:00:00","2021-03-06T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-11T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-02T00:00:00","2021-04-03T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-08T00:00:00","2021-04-10T00:00:00","2021-04-13T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-01T00:00:00","2021-05-02T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-07T00:00:00","2021-05-08T00:00:00","2021-05-10T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-04T00:00:00","2021-06-05T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-2 ...

# %%
kt.plot(forecast)
pyplot.show()

# %%
initial_days = (df.ds.max() - df.ds.min()) / np.timedelta64(1, 'D')
period_days = initial_days - 365
period_days
# Out:
# 333.0

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(kt, initial='100 days', period='100 days', horizon='365 days')
# Out:
# INFO:prophet:Making 3 forecasts with cutoffs between 2020-05-24 00:00:00 and 2020-12-10 00:00:00
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:fbprophet:n_changepoints greater than number of observations. Using 4.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.

# %%
df_cv.head()
# Out:
#           ds        yhat  yhat_lower  yhat_upper           y     cutoff
# 0 2020-06-11  175.075607  157.868692  191.486245  139.000000 2020-05-24
# 1 2020-07-12  167.282447  151.642986  183.764159  183.550003 2020-05-24
# 2 2020-08-12  140.748542  123.701288  157.537179  181.800003 2020-05-24
# 3 2020-09-11  115.061843   97.319947  132.755402  141.000000 2020-05-24
# 4 2020-09-12  119.332276  102.401453  136.315379  182.699997 2020-05-24

# %%
cutoff = df_cv['cutoff'].unique()[0]
cutoff
# Out:
# numpy.datetime64('2020-05-24T00:00:00.000000000')

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head(10)
# Out:
#   horizon           mse        rmse         mae      mape     mdape     smape  \
# 0 71 days  13840.673376  117.646391   91.529888  0.305340  0.358819  0.385054
# 1 72 days  13842.640665  117.654752   91.598804  0.305717  0.358819  0.385462
# 2 73 days  13842.929141  117.655978   91.609588  0.306097  0.358819  0.385877
# 3 74 days  14194.428558  119.140373   93.961820  0.313310  0.376896  0.395510
# 4 75 days  14651.638201  121.043952   96.729208  0.321428  0.379337  0.406481
# 5 76 days  15064.385170  122.737057   99.169687  0.328104  0.383297  0.415680
# 6 77 days  15528.790764  124.614569  102.031297  0.336517  0.402779  0.426776
# 7 78 days  15992.622358  126.461940  104.701737  0.343972  0.403364  0.436979
# 8 79 days  15993.099920  126.463829  104.776788  0.344420  0.403364  0.437436
# 9 80 days  16033.346393  126.622851  105.640001  0.348890  0.403364  0.443154
#
#    coverage
# 0  0.301887
# 1  0.301887
# 2  0.301887
# 3  0.283019
# 4  0.264151
# 5  0.245283
# 6  0.216981
# 7  0.207547
# 8  0.207547
# 9  0.179245

# %%
df_p.mean().to_frame()
# Out:
#                                     0
# horizon   221 days 15:45:59.124087592
# mse                      25513.277205
# rmse                       157.098365
# mae                        144.749284
# mape                         0.461883
# mdape                        0.489937
# smape                        0.625194
# coverage                     0.057487

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mse')

# %%
fig = plot_cross_validation_metric(df_cv, metric='rmse')
